# %% [markdown]
# # <center>Music & Mental Health Survey Results Analysis</center>

# %% [markdown]
# ### Project Approach
#
# - [Problem Statement](#sec1)
# <br><br>
# - [Data Collection and Description](#sec2)
# <br><br>
# - [Data Cleaning](#sec3)
# <br><br>
# - [Feature Engineering](#sec4)
# <br><br>
# - [Exporting Cleaned Data to CSV](#sec5)
# <br><br>
# - [Exploratory Data Analysis](#sec6)
# <br><br>
# - [Univariate Analysis](#sec7)
# <br><br>
# - [Bivariate Analysis](#sec8)
# <br><br>
# - [Multivariate Analysis](#sec9)
# <br><br>
# - [Integration of MySQL to Python](#sec10)

# %% [markdown]
# <a id=sec1></a>
# ## Problem Statement

# %% [markdown]
# - In this project, I'll conduct an Exploratory Data Analysis (EDA) on a dataset related to research on Music Therapy. The goal is to explore the potential correlations between participants' favorite music genres and their mental health.
# - The aim is to uncover meaningful connections between music preferences and mental health, which can contribute to the effective application of Music Therapy and provide valuable insights into the psychological impact of different music genres. 🎼🧠

# %% [markdown]
# ### About the Dataset

# %% [markdown]
# - The MxMH dataset aims to identify what, if any, correlations exist between an individual's music taste and their self-reported mental health.
# - The dataset has 33 Columns that contains the following information about an individual:
#
# #### Dataset Columns
# - __Timestamp:__ Date and time when form was submitted
# - __Age:__ Respondent's age
# - __Primary streaming service:__ Respondent's primary streaming service
# - __Hours per day:__ Number of hours the respondent listens to music per day
# - __While working:__ Does the respondent listen to music while studying/working?
# - __Instrumentalist:__ Does the respondent play an instrument regularly?
# - __Composer:__ Does the respondent compose music?
# - __Fav genre:__ Respondent's favorite or top genre
# - __Exploratory:__ Does the respondent actively explore new artists/genres?
# - __Foreign languages:__ Does the respondent regularly listen to music with lyrics in a language they are not fluent in?
# - __BPM:__ Beats per minute of favorite genre
# - __Frequency [Classical]:__ How frequently the respondent listens to classical music
# - __Frequency [Country]:__ How frequently the respondent listens to country music
# - __Frequency [EDM]:__ How frequently the respondent listens to EDM music
# - __Frequency [Folk]:__ How frequently the respondent listens to folks music
# - __Frequency [Gospel]:__ How frequently the respondent listens to Gospel music
# - __Frequency [Hip hop]:__ How frequently the respondent listens to hip hop music
# - __Frequency [Jazz]:__ How frequently the respondent listens to jazz music
# - __Frequency [K pop]:__ How frequently the respondent listens to K pop music
# - __Frequency [Latin]:__ How frequently the respondent listens to Latin music
# - __Frequency [Lofi]:__ How frequently the respondent listens to lofi music
# - __Frequency [Metal]:__ How frequently the respondent listens to metal music
# - __Frequency [Pop]:__ How frequently the respondent listens to pop music
# - __Frequency [R&B]:__ How frequently the respondent listens to R&B music
# - __Frequency [Rap]:__ How frequently the respondent listens to rap music
# - __Frequency [Rock]:__ How frequently the respondent listens to rock music
# - __Frequency [Video game music]:__ How frequently the respondent listens to video game music
# - __Anxiety:__ Self-reported anxiety, on a scale of 0-10
# - __Depression:__ Self-reported depression, on a scale of 0-10
# - __Insomnia:__ Self-reported insomnia, on a scale of 0-10
# - __OCD:__ Self-reported OCD, on a scale of 0-10
# - __Music effects:__ Does music improve/worsen respondent's mental health conditions?
# - __Permissions:__ Permissions to publicize data

# %% [markdown]
# <a id=sec2></a>
# ## Data Collection and Description

# %% [markdown]
# __Importing Required Packages__

# %%
import pandas as pd                            # Used for data manipulation and analysis
import numpy as np                             # Implemennts milti-dimensional array and matrices
import matplotlib.pyplot as plt                # Plotting library for Python and it's numerical mathematics extension NumPy
# %matplotlib inline
import seaborn as sns                          # Provides a high level interface for drawing attractive and informative graphs
import warnings
warnings.filterwarnings("ignore")              # Ignore all warnings
sns.set(rc={"figure.figsize":(15,6)})
plt.style.use('fivethirtyeight')
pd.set_option("display.max_columns",None)      # Display all the columns of the dataframe

# %% [markdown]
# __Importing the Dataset__

# %%
data = pd.read_csv("mxmh_survey_results.csv")

# %% [markdown]
# __Understanding The Data__

# %%
# Displaying shape of dataset
f'The data contains {data.shape[0]} Rows and {data.shape[1]} Columns'
# Out:
# 'The data contains 736 Rows and 33 Columns'

# %%
# Displaying the column names
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary streaming service', 'Hours per day',
#        'While working', 'Instrumentalist', 'Composer', 'Fav genre',
#        'Exploratory', 'Foreign languages', 'BPM', 'Frequency [Classical]',
#        'Frequency [Country]', 'Frequency [EDM]', 'Frequency [Folk]',
#        'Frequency [Gospel]', 'Frequency [Hip hop]', 'Frequency [Jazz]',
#        'Frequency [K pop]', 'Frequency [Latin]', 'Frequency [Lofi]',
#        'Frequency [Metal]', 'Frequency [Pop]', 'Frequency [R&B]',
#        'Frequency [Rap]', 'Frequency [Rock]', 'Frequency [Video game music]',
#        'Anxiety', 'Depression', 'Insomnia', 'OCD', 'Music effects',
#        'Permissions'],
#       dtype='object')

# %%
#information about the datatypes of columns
data.dtypes
# Out:
# Timestamp                        object
# Age                             float64
# Primary streaming service        object
# Hours per day                   float64
# While working                    object
# Instrumentalist                  object
# Composer                         object
# Fav genre                        object
# Exploratory                      object
# Foreign languages                object
# BPM                             float64
# Frequency [Classical]            object
# Frequency [Country]              object
# Frequency [EDM]                  object
# Frequency [Folk]                 object
# Frequency [Gospel]               object
# Frequency [Hip hop]              object
# Frequency [Jazz]                 object
# Frequency [K pop]                object
# Frequency [Latin]                object
# Frequency [Lofi]                 object
# Frequency [Metal]                object
# Frequency [Pop]                  object
# ...

# %%
#overview of the dataset
data.head()
# Out:
#             Timestamp   Age Primary streaming service  Hours per day  \
# 0  8/27/2022 19:29:02  18.0                   Spotify            3.0
# 1  8/27/2022 19:57:31  63.0                   Pandora            1.5
# 2  8/27/2022 21:28:18  18.0                   Spotify            4.0
# 3  8/27/2022 21:40:40  61.0             YouTube Music            2.5
# 4  8/27/2022 21:54:47  18.0                   Spotify            4.0
#
#   While working Instrumentalist Composer         Fav genre Exploratory  \
# 0           Yes             Yes      Yes             Latin         Yes
# 1           Yes              No       No              Rock         Yes
# 2            No              No       No  Video game music          No
# 3           Yes              No      Yes              Jazz         Yes
# 4           Yes              No       No               R&B         Yes
#
#   Foreign languages    BPM Frequency [Classical] Frequency [Country]  \
# ...

# %%
#information about the datatypes of columns
data.dtypes
# Out:
# Timestamp                        object
# Age                             float64
# Primary streaming service        object
# Hours per day                   float64
# While working                    object
# Instrumentalist                  object
# Composer                         object
# Fav genre                        object
# Exploratory                      object
# Foreign languages                object
# BPM                             float64
# Frequency [Classical]            object
# Frequency [Country]              object
# Frequency [EDM]                  object
# Frequency [Folk]                 object
# Frequency [Gospel]               object
# Frequency [Hip hop]              object
# Frequency [Jazz]                 object
# Frequency [K pop]                object
# Frequency [Latin]                object
# Frequency [Lofi]                 object
# Frequency [Metal]                object
# Frequency [Pop]                  object
# ...

# %%
#get the concise summary of the data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 33 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Timestamp                     736 non-null    object
#  1   Age                           735 non-null    float64
#  2   Primary streaming service     735 non-null    object
#  3   Hours per day                 736 non-null    float64
#  4   While working                 733 non-null    object
#  5   Instrumentalist               732 non-null    object
#  6   Composer                      735 non-null    object
#  7   Fav genre                     736 non-null    object
#  8   Exploratory                   736 non-null    object
#  9   Foreign languages             732 non-null    object
#  10  BPM                           629 non-null    float64
#  11  Frequency [Classical]         736 non-null    object
# ...

# %%
#Descriptive Analysis of dataset
data.describe(include='all')
# Out:
#                  Timestamp         Age Primary streaming service  \
# count                  736  735.000000                       735
# unique                 735         NaN                         6
# top     8/28/2022 16:15:08         NaN                   Spotify
# freq                     2         NaN                       458
# mean                   NaN   25.206803                       NaN
# std                    NaN   12.054970                       NaN
# min                    NaN   10.000000                       NaN
# 25%                    NaN   18.000000                       NaN
# 50%                    NaN   21.000000                       NaN
# 75%                    NaN   28.000000                       NaN
# max                    NaN   89.000000                       NaN
#
#         Hours per day While working Instrumentalist Composer Fav genre  \
# count      736.000000           733             732      735       736
# ...

# %% [markdown]
# <a id = sec3></a>
# ## Data Cleaning

# %% [markdown]
# __Handling Missing Values & duplicate Values__

# %%
# Check null values in dataset
data.isna().sum().sort_values(ascending=False)
# Out:
# BPM                             107
# Music effects                     8
# Foreign languages                 4
# Instrumentalist                   4
# While working                     3
# Primary streaming service         1
# Composer                          1
# Age                               1
# Timestamp                         0
# Exploratory                       0
# Fav genre                         0
# Frequency [Classical]             0
# Frequency [Country]               0
# Frequency [EDM]                   0
# Frequency [Folk]                  0
# Frequency [Gospel]                0
# Hours per day                     0
# Frequency [Hip hop]               0
# Frequency [Jazz]                  0
# Frequency [Latin]                 0
# Frequency [K pop]                 0
# Frequency [Metal]                 0
# Frequency [Pop]                   0
# Frequency [R&B]                   0
# Frequency [Lofi]                  0
# Frequency [Rap]                   0
# ...

# %%
# Drop null values from the columns where count of null values are less than 10
data.dropna(subset=['Music effects','Foreign languages','Instrumentalist','While working','Primary streaming service','Composer','Age'],inplace=True)

# %%
# Since BPM has a lot of null values, we can replace them with the mean value of specific genre
miss_bpm_genre = data[data['BPM'].isnull() == True]['Fav genre'].unique()
for i in miss_bpm_genre:
  data['BPM'] = data['BPM'].fillna(round(data[data['Fav genre']== i ]['BPM'].mean(), 0))

# %%
data.isna().sum().sort_values(ascending=False)
# Out:
# Timestamp                       0
# Age                             0
# Primary streaming service       0
# Hours per day                   0
# While working                   0
# Instrumentalist                 0
# Composer                        0
# Fav genre                       0
# Exploratory                     0
# Foreign languages               0
# BPM                             0
# Frequency [Classical]           0
# Frequency [Country]             0
# Frequency [EDM]                 0
# Frequency [Folk]                0
# Frequency [Gospel]              0
# Frequency [Hip hop]             0
# Frequency [Jazz]                0
# Frequency [K pop]               0
# Frequency [Latin]               0
# Frequency [Lofi]                0
# Frequency [Metal]               0
# Frequency [Pop]                 0
# Frequency [R&B]                 0
# Frequency [Rap]                 0
# Frequency [Rock]                0
# Frequency [Video game music]    0
# ...

# %%
# check duplicate value in dataset
data.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# __Handling Outliers__

# %%
#Graphical Representation of Outliers initially
columns = data.select_dtypes(exclude="object").columns
colors = sns.color_palette("Spectral", len(columns))
for i in range(0,len(columns)):
    plt.subplot(2,4,i+1)
    sns.boxplot(x=data[columns[i]], color=colors[i])
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %%
# Outlier Detection and Removal Using IQR
for col in columns:
    Q1 = data[col].quantile(0.25)
    Q3 = data[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # Outlier Detection
    outliers = ((data[col] < lower_bound) | (data[col] > upper_bound))
    num_outliers = outliers.sum()
    print(f'{col}:{num_outliers}')
    
    # Removing Outliers
    data = data[(data[col] >= lower_bound) & (data[col] <= upper_bound)].reset_index(drop=True)
# Out:
# Age:57
# Hours per day:35
# BPM:21
# Anxiety:0
# Depression:0
# Insomnia:0
# OCD:0

# %%
#Graphical Representation of Data after removing Outliers
colors = sns.color_palette("husl", len(columns))
for i in range(0,len(columns)):
    plt.subplot(2,4,i+1)
    sns.boxplot(x=data[columns[i]], color=colors[i])
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %%
#Shape of data after cleaning
print(f'The Shape of data after cleaning is: {data.shape}')
# Out:
# The Shape of data after cleaning is: (605, 33)

# %% [markdown]
# <a id = sec4></a>
# ## Feature Engineering

# %%
#Displaying the unique values

for i in data.columns:
    print("\n",i.center(75,"*"),"\n")
    # get unique values
    n = data[i].unique()
    
    # if number of unique values is less than 45, print the values. Otherwise print the number of unique values
    if len(n)<45:
        print("\n", n,"\n")     
    else:
        print(i + ': ' +str(len(n)) + ' unique values')
# Out:
#  *********************************Timestamp*********************************
#
# Timestamp: 604 unique values
#
#  ************************************Age************************************
#
#
#  [18. 21. 19. 17. 16. 15. 20. 26. 23. 37. 36. 24. 22. 25. 32. 29. 41. 31.
#  14. 33. 30. 43. 28. 34. 13. 35. 27. 42. 38. 40. 10. 12. 39.]
#
#
#  *************************Primary streaming service*************************
#
#
#  ['Spotify' 'YouTube Music' 'I do not use a streaming service.'
#  'Apple Music' 'Other streaming service' 'Pandora']
#
#
#  *******************************Hours per day*******************************
#
#
#  [4.   5.   3.   1.   6.   8.   2.   0.5  0.25 7.   2.5  1.5  9.   0.7
#  4.5  0.   0.1 ]
#
#
#  *******************************While working*******************************
#
#
#  ['No' 'Yes']
#
#
#  ******************************Instrumentalist******************************
#
#
#  ['No' 'Yes']
#
#
# ...

# %% [markdown]
# __Modifying Column Labels__

# %%
data.columns = data.columns.str.replace(" ", "_")
data.columns = data.columns.str.replace("[", "")
data.columns = data.columns.str.replace("]", "")
data.columns
# Out:
# Index(['Timestamp', 'Age', 'Primary_streaming_service', 'Hours_per_day',
#        'While_working', 'Instrumentalist', 'Composer', 'Fav_genre',
#        'Exploratory', 'Foreign_languages', 'BPM', 'Frequency_Classical',
#        'Frequency_Country', 'Frequency_EDM', 'Frequency_Folk',
#        'Frequency_Gospel', 'Frequency_Hip_hop', 'Frequency_Jazz',
#        'Frequency_K_pop', 'Frequency_Latin', 'Frequency_Lofi',
#        'Frequency_Metal', 'Frequency_Pop', 'Frequency_R&B', 'Frequency_Rap',
#        'Frequency_Rock', 'Frequency_Video_game_music', 'Anxiety', 'Depression',
#        'Insomnia', 'OCD', 'Music_effects', 'Permissions'],
#       dtype='object')

# %% [markdown]
# __Removing Not Needed Columns__

# %%
# Removing Permissions column as it contains single value. Hence, it will not be contributing in further Analysis 
data.drop(['Permissions'], axis=1, inplace=True)

# %%
# Creating Date column by extracting date from Timestamp column for better analysis
data['Date'] = pd.to_datetime(data['Timestamp']).dt.date

# %%
# Removing Timestamp column as we have already extracted dates from it and there is Hours_per_day column to time analysis.
data.drop(['Timestamp'], axis=1, inplace=True)

# %% [markdown]
# <a id = sec5></a>
# ## Exporting Cleaned Data to CSV

# %%
#Export the final processed dataset to a CSV file for further analysis and visualization
data.to_csv('Cleaned_MxMH.csv', index=False)

# %% [markdown]
# <a id = sec6></a>
# ## Exploratory Data Analysis

# %%
#Loading Cleaned Data for Further Analysis
df = pd.read_csv('Cleaned_MxMH.csv')

# %%
#Statistical Information in the Table Format.
df.describe()[1:].T.style.background_gradient(cmap='viridis', axis=1)
# Out:
# <style type="text/css">
# #T_4e63c_row0_col0 {
#   background-color: #27808e;
#   color: #f1f1f1;
# }
# #T_4e63c_row0_col1, #T_4e63c_row1_col2, #T_4e63c_row2_col1, #T_4e63c_row3_col2, #T_4e63c_row4_col2, #T_4e63c_row5_col2, #T_4e63c_row6_col2, #T_4e63c_row6_col3 {
#   background-color: #440154;
#   color: #f1f1f1;
# }
# #T_4e63c_row0_col2 {
#   background-color: #482173;
#   color: #f1f1f1;
# }
# #T_4e63c_row0_col3 {
#   background-color: #33638d;
#   color: #f1f1f1;
# }
# #T_4e63c_row0_col4 {
#   background-color: #2a778e;
#   color: #f1f1f1;
# }
# #T_4e63c_row0_col5 {
#   background-color: #20928c;
#   color: #f1f1f1;
# }
# #T_4e63c_row0_col6, #T_4e63c_row1_col6, #T_4e63c_row2_col6, #T_4e63c_row3_col6, #T_4e63c_row4_col6, #T_4e63c_row5_col6, #T_4e63c_row6_col6 {
#   background-color: #fde725;
#   color: #000000;
# }
# #T_4e63c_row1_col0 {
#   background-color: #306a8e;
#   color: #f1f1f1;
# }
# #T_4e63c_row1_col1, #T_4e63c_row1_col3 {
#   background-color: #3e4989;
# ...

# %% [markdown]
# __Separating catigorical and numerical features__

# %%
catigorical_features = df.select_dtypes(include="object").columns
numerical_features = df.select_dtypes(exclude="object").columns

# %%
catigorical_features
# Out:
# Index(['Primary_streaming_service', 'While_working', 'Instrumentalist',
#        'Composer', 'Fav_genre', 'Exploratory', 'Foreign_languages',
#        'Frequency_Classical', 'Frequency_Country', 'Frequency_EDM',
#        'Frequency_Folk', 'Frequency_Gospel', 'Frequency_Hip_hop',
#        'Frequency_Jazz', 'Frequency_K_pop', 'Frequency_Latin',
#        'Frequency_Lofi', 'Frequency_Metal', 'Frequency_Pop', 'Frequency_R&B',
#        'Frequency_Rap', 'Frequency_Rock', 'Frequency_Video_game_music',
#        'Music_effects', 'Date'],
#       dtype='object')

# %%
numerical_features
# Out:
# Index(['Age', 'Hours_per_day', 'BPM', 'Anxiety', 'Depression', 'Insomnia',
#        'OCD'],
#       dtype='object')

# %% [markdown]
# - **What is the distribution of the demographic variables?**

# %%
colmns1 = ['Primary_streaming_service', 'Music_effects', 'Fav_genre', 'While_working']

for i in range(0,len(colmns1)):
    plt.subplot(1,4,i+1)
    sns.countplot(x=df[colmns1[i]], palette="husl")
    
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %% [markdown]
# - Spotifiy and Youtube streaming services are preferred by most of the respondents.
# - Listening to music results in improving the mental health for most of the respondets.
# - Most respondents like to listen to music while working.

# %%
colmns1 = ['Instrumentalist', 'Exploratory', 'Composer', 'Foreign_languages']
palette = ["#935471", "#F3C232"]
plt.figure(figsize = (16,4))

for i in range(0,len(colmns1)):
    plt.subplot(1,4,i+1)
    sns.countplot(x=df[colmns1[i]], palette=palette) #icefire
    
    plt.xticks(size=15,rotation=90)
    plt.tight_layout()

# %% [markdown]
# - **What is the distribution of Numerical Features ?**

# %%
fig, axes = plt.subplots(2, 4, figsize=(12, 5))
fig.suptitle("Distribution Graphs of numerical features", fontsize=14)
colors = sns.color_palette("husl", len(columns))

for i, ax in enumerate(axes.flat):
    if i < len(numerical_features):
        #sns.distplot(df[numerical_features[i]], ax=ax)
        sns.violinplot(y=df[numerical_features[i]], ax=ax, color=colors[i])
        ax.set_xticks([])
        ax.set_xticklabels([], size=15, rotation=90)
    else:
        ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Most of the respondents are youngesters of age group 15-25.
# - Most of the respondents listens to the music for 2 to 2.5 hours pre day generally.
# - Most of the respondents listens to the music with 100 to 125 beats per minute.

# %% [markdown]
# <a id = sec7></a>
# ## Univariate Analysis

# %% [markdown]
# - **Which is the most used streaming service?**

# %%
plt.figure(figsize=(12,6))
sns.countplot(x=df['Primary_streaming_service'], palette = "husl")
plt.xticks(rotation=30)
plt.show()

# %% [markdown]
# - Spotify is the most used streaming service.
# - Pandora is the least used streaming service

# %% [markdown]
# - **How many people like to hear music while working?**

# %%
color = ['#47B39C', '#FFC154']
plt.figure(figsize=(10,4))
plt.pie(df.While_working.value_counts(ascending=False), labels=['Likes', 'Does not Like'], explode=(0.2,0), autopct='%1.1f%%', colors=color)
plt.title('Listening to Music While Working', fontsize=18)
plt.show()

# %% [markdown]
# - Around __79%__ people Likes to hear music while working.
# - Listening to music while working may increase the productivity.

# %% [markdown]
# - **How People Experience the Effects of Music on Mental Health?**

# %%
plt.figure(figsize=(10,4))
sns.countplot(x=df['Music_effects'], palette='husl')
plt.show()

# %% [markdown]
# - The majority of respondents reported that music improves their mental health.
# - The very low count of "Worsen" category indicates that music rarely has a negative impact, but it can for some individuals.

# %% [markdown]
# <a id = sec8></a>
# ## Bivariate Analysis

# %% [markdown]
# - **Preferred Genre According to Age**

# %%
plt.figure(figsize=(12,6))
sns.histplot(data=df, x='Age', hue='Fav_genre', multiple='stack', kde=True, palette='husl')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Rock, Pop and Metal are the most famous Genre in all age groups.
# - Younger age groups shows a diverse range of musical preferences
# - Gospel and Latin are the least preferred music genres.

# %% [markdown]
# - **Impact of Music Genres on Anxiety Levels**

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Fav_genre'], y=df['Anxiety'], palette='husl', errwidth=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Every listener has Anxiety level above 4 except Gospel Listeners.
# - Jazz, K pop, Rock, Pop, Hip hop, Folk, and Lofi music listeners have anxiety levey above 6
# - Latin listeners have highest anxiety level (approx. 10)

# %% [markdown]
# - **Impacts of Music Genres on Depression Levels**

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Fav_genre'], y=df['Depression'], palette='husl', errwidth=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Evey listener have Depression levels above 4 except Gospel listeners with 0 Deoression level.
# - Lofi, Hip hop, Rock, Latin and Folk listeners have Depression level above 5.

# %% [markdown]
# - **Impacts of Music Genres on Insomnia Levels**

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Fav_genre'], y=df['Insomnia'], palette='husl', errwidth=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Every listener have Insomnia level below 4, except Metal and Lofi.
# - 0 level of Insomnia indicates that Latin listeners do not have Insomnia.

# %% [markdown]
# - **Impacts of Music Genres on OCD(Obsessive-Compulsive Disorder) Levels**

# %%
plt.figure(figsize=(12,6))
sns.barplot(x=df['Fav_genre'], y=df['OCD'].sort_values(), palette='husl', errwidth=0)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Only Rap and Lofi listeners have the OCD levels above 3.
# - Folk and Gospel listeners have the second-lowest OCD levels
# - 0 level of OCD indicates that Latin listeners do not have OCD

# %% [markdown]
# <a id = sec9></a>
# ## Multivariate Analysis

# %%
plt.figure(figsize=(8,6))
sns.barplot(x=df['Fav_genre'], y=df['BPM'], hue=df['Music_effects'], errwidth=0, palette='husl')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# - Beats per minute are below 130 for all the Genres except for EDM, Classical and Metal.
# - Lestening Classical genre in Faster beats worsen the mental health.
# - Lofi, Gospel and Latin Music Genres have only improved mental health cases.
# - Video game music, Rock, pop, Rap and Classical Music Genres Have some worsen mental health cases.

# %%
plt.figure(figsize=(8,6))
correlation_matrix = df[['Anxiety', 'Depression', 'Insomnia', 'OCD']].corr()
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation among Psychological Variables')
plt.show()

# %% [markdown]
# - All the disorders are positively related to each other.
# - Anxiety and Depression are the highest correlated disorders in the given dataset.
# - OCD is the least affected disorder by any other disorder in the given dataset.

# %%
fig = plt.figure(figsize=(16, 6))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(df['Anxiety'], df['Depression'], df['Age'], c=df['Age'], cmap='viridis', s=50)
ax.set_xlabel('Anxiety')
ax.set_ylabel('Depression')
ax.set_zlabel('Age')
plt.title("3D Scatter: Age vs Anxiety vs Depression")

cbar = plt.colorbar(sc, ax=ax, shrink=0.6, pad=0.1)
cbar.set_label("Age") 

plt.show()

# %% [markdown]
# - Younger people might be more vulnerable to high Anxiety and Depression levels.
# - Older individuals could have better coping mechanisms or resilience towards Anxiety and Depression.

# %% [markdown]
# <a id = sec10></a>
# ## Integration of MySQL to Python

# %%
# from sqlalchemy import create_engine

# %%
# engine = create_engine("mysql+pymysql://root:adiya123@localhost/constructweek")
# print("Connected to MySQL successfully!")
# Out:
# Connected to MySQL successfully!

# %%
# df.to_sql("Cleaned_MxMH", con=engine, if_exists="replace", index=False)
# # "replace" will create the table automatically and overwrite if it exists.
# # Use "append" if you want to add data without deleting the existing one.

# print("CSV data inserted successfully into MySQL!")
# Out:
# CSV data inserted successfully into MySQL!
